# %% [markdown]
# # NLTK with Naive Bayes

# %%
# open python and nltk packages needed for processing
import os
import sys
import random
import nltk
from nltk.corpus import stopwords
from nltk.corpus import sentence_polarity
import re
from sklearn.feature_extraction.text import CountVectorizer 
from nltk import FreqDist
from nltk.collocations import *
from nltk.metrics import ConfusionMatrix
from nltk.corpus import stopwords
from cleantext import clean
from LIWCtools.LIWCtools import *
#from liwc import Liwc
from cleantext import clean
import cleantext
import sentiment_read_LIWC_pos_neg_words

bigram_measures = nltk.collocations.BigramAssocMeasures()

# %% [markdown]
# #### - Featureset funct

# %%
##HERE IS THE CODE TO ADD OR CHANGE FEATURES
##THIS PARTICULAR CODE CREATES DE BASELINE AS BAG OF WORDS (BOW) OR UNIGRAMS
# each feature is 'V_(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    return features

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend([',', '.', '-', 'movie', 'film', '``', '`', "'", "...", '--'])

# %%
# negation
def Not_features(document, word_features, negationwords):
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = False
        features['V_NOT{}'.format(word)] = False
    # go through document words in order
    for i in range(0, len(document)):
        word = document[i]
        if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
            i += 1
            features['V_NOT{}'.format(document[i])] = (document[i] in word_features)
        else:
            features['V_{}'.format(word)] = (word in word_features)
    return features

# this list of negation words includes some "approximate negators" like hardly and rarely
negationwords = ['no', 'not', 'never', 'none', 'nowhere', 'nothing', 'noone', 'rather', 'hardly', 'scarcely', 
                 'rarely', 'seldom', 'neither', 'nor']

# %%
# define features that include words as before 
# add the most frequent significant bigrams
# this function takes the list of words in a document as an argument and returns a feature dictionary
# it depends on the variables word_features and bigram_features
def bigram_document_features(document, word_features, bigram_features):
    document_words = set(document)
    document_bigrams = nltk.bigrams(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    for bigram in bigram_features:
        features['B_{}_{}'.format(bigram[0], bigram[1])] = (bigram in document_bigrams)    
    return features

# %%
# bigram_featuresets

# this function takes the number of folds, the feature sets
# it iterates over the folds, using different sections for training and testing in turn
#   it prints the accuracy for each fold and the average accuracy at the end
def cross_validation_accuracy(num_folds, bigram_featuresets):
    subset_size = int(len(bigram_featuresets)/num_folds)
    print('Each fold size:', subset_size)
    accuracy_list = []
    # iterate over the folds
    for i in range(num_folds):
        test_this_round = bigram_featuresets[(i*subset_size):][:subset_size]
        train_this_round = bigram_featuresets[:(i*subset_size)] + bigram_featuresets[((i+1)*subset_size):]
        # train using train_this_round
        classifier = nltk.NaiveBayesClassifier.train(train_this_round)
        # evaluate against test_this_round and save accuracy
        accuracy_this_round = nltk.classify.accuracy(classifier, test_this_round)
        print (i, accuracy_this_round)
        accuracy_list.append(accuracy_this_round)
    # find mean accuracy over all rounds
    print ('mean accuracy', sum(accuracy_list) / num_folds)

# %%
def readSubjectivity(path): # pass to where the file is
    flexicon = open(path, 'r')
    # initialize an empty dictionary
    sldict = { } # starts a dictionary 
    for line in flexicon: # for each line
        fields = line.split()   # default is to split on whitespace
        # split each field on the '=' and keep the second part as the value
        strength = fields[0].split("=")[1]
        word = fields[2].split("=")[1]
        posTag = fields[3].split("=")[1]
        stemmed = fields[4].split("=")[1]
        polarity = fields[5].split("=")[1]
        if (stemmed == 'y'):
            isStemmed = True
        else:
            isStemmed = False
        # put a dictionary entry with the word as the keyword
        #     and a list of the other values
        sldict[word] = [strength, posTag, isStemmed, polarity]
    return sldict

# %%
SLpath = "./SentimentLexicons/subjclueslen1-HLTEMNLP05.tff"
SL = readSubjectivity(SLpath)
len(SL.keys())
# Out:
# 6885

# %%
# define features that include word counts of subjectivity words
# negative feature will have number of weakly negative words +
#    2 * number of strongly negative words
# positive feature has similar definition
#    not counting neutral words
def SL_features(document, word_features, SL): #add polarity feature as well, takes doc, features and lexicon
    document_words = set(document) # 2000 feature 
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    # count variables for the 4 classes of subjectivity
    weakPos = 0
    strongPos = 0
    weakNeg = 0
    strongNeg = 0
    for word in document_words:
        if word in SL:
            strength, posTag, isStemmed, polarity = SL[word]
            if strength == 'weaksubj' and polarity == 'positive':
                weakPos += 1
            if strength == 'strongsubj' and polarity == 'positive':
                strongPos += 1
            if strength == 'weaksubj' and polarity == 'negative':
                weakNeg += 1
            if strength == 'strongsubj' and polarity == 'negative':
                strongNeg += 1
            features['positivecount'] = weakPos + (2 * strongPos) # added features; count the numb of pos and neg
            features['negativecount'] = weakNeg + (2 * strongNeg)      
    return features

# %%
poslist,neglist = sentiment_read_LIWC_pos_neg_words.read_words()
#print(poslist,neglist)
poslist = poslist
neglist = neglist
#print(poslist)
#print(neglist)

# %%
def liwc_features(document, word_features, poslist, neglist):  
    document_words = set(document)
    features = {}  
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
        pos = 0
        neg = 0
    for word in document_words:     
        if sentiment_read_LIWC_pos_neg_words.isPresent(word,poslist):   
            pos += 1
        if sentiment_read_LIWC_pos_neg_words.isPresent(word,neglist):       
            neg += 1     
            features['positivecount'] = pos
            features['negativecount'] = neg
        if 'positivecount' not in features: 
            features['positivecount']=0   
        if 'negativecount' not in features:
            features['negativecount']=0
    return features

# %%
def SL_liwc_features(document, word_features, SL,poslist,neglist):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
        # count variables for the 4 classes of subjectivity
        weakPos = 0
        strongPos = 0
        weakNeg = 0
        strongNeg = 0
    for word in document_words:
        if sentiment_read_LIWC_pos_neg_words.isPresent(word,poslist):
            strongPos += 1
        elif sentiment_read_LIWC_pos_neg_words.isPresent(word,neglist):
            strongNeg += 1
        elif word in SL:
            strength, posTag, isStemmed, polarity = SL[word]
            if strength == 'weaksubj' and polarity == 'positive':
                weakPos += 1
            if strength == 'strongsubj' and polarity == 'positive':
                strongPos += 1
            if strength == 'weaksubj' and polarity == 'negative':
                weakNeg += 1
            if strength == 'strongsubj' and polarity == 'negative':
                strongNeg += 1
    features['positivecount'] = weakPos + (2 * strongPos)
    features['negativecount'] = weakNeg + (2 * strongNeg)
    if 'positivecount' not in features:
        features['positivecount']=0
    if 'negativecount' not in features:
        features['negativecount']=0      
    return features

# %%
# All features combined
def combined_document_features(document, word_features, SL, bigram_features, negationwords):
    document_words = set(document)
    document_bigrams = nltk.bigrams(document)
    features = {}
    # Subjectivity
    weakPos = 0
    strongPos = 0
    weakNeg = 0
    strongNeg = 0
    for word in document_words:
        if word in SL:
            strength, posTag, isStemmed, polarity = SL[word]
            if strength == 'weaksubj' and polarity == 'positive':
                weakPos += 1
            if strength == 'strongsubj' and polarity =='positive':
                strongPos += 1
            if strength == 'weaksubj' and polarity == 'negative':
                weakNeg += 1
            if strength == 'strongsubj' and polarity == 'negative':
                strongNeg += 1
            features['positiveStrengthCount'] = (2 * weakPos) + (5 * strongPos)
            features['negativeStrengthCount'] = (2 * weakNeg) + (5 * strongNeg)
        for word in word_features:
            features['V_{}'.format(word)] = False
            features['V_NOT{}'.format(word)] = False
        for word in word_features:
            for i in range(0, len(document)):
                word = document[i]
                if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
                    i += 1
                    features['V_NOT{}'.format(document[i])] = (document[i] in word_features)
                else:
                    features['V_{}'.format(word)] = (word in word_features)
        for bigram in bigram_features:
            features['B_{}_{}'.format(bigram[0], bigram[1])] = (bigram in document_bigrams)
            return features

# %%
def generate_SLneg_features(document, SL, negationwords):
    document_words = set(document)
    features = {}
    features['length'] = len(document_words)
    weakPos = 0
    strongPos = 0
    weakNeg = 0
    strongNeg = 0
    negationWords = 0
    psc = 0
    nsc = 0
    for word in document_words:
        if word in negationwords:
            negationWords +=1
        features['negationwords'] = negationWords
        if word in SL:
            strength, posTag, isStemmed, polarity = SL[word]
            if strength == 'weaksubj' and polarity == 'positive':
                weakPos += 1
            if strength == 'strongsubj' and polarity == 'positive':
                strongPos += 1
            if strength == 'weaksubj' and polarity == 'negative': 
                weakNeg += 1
            if strength == 'strongsubj' and polarity == 'negative':
                strongNeg += 1
            psc = (weakPos) + (strongPos)   
            nsc = (weakNeg) + (strongNeg) 
            features['positiveStrengthCount'] = (2 * weakPos) + (5 * strongPos)      
            features['negativeStrengthCount'] = (2 * weakNeg) + (5 * strongNeg)
        length = len(document_words)
        if length > 10:
            features['percpositive'] = round(psc/length*100,2)
            features['percnegative'] = round(nsc/length*100,2)
        print(features)
        return features

# %%
def not_features(document, word_features, bigram_features, negationwords):
    document_words = set(document)
    document_bigrams = nltk.bigrams(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    for bigram in bigram_features:
        features['B_{}_{}'.format(bigram[0], bigram[1])] = (bigram in document_bigrams)
        #go through document words in order
    for i in range(0, len(document)):
        word = document[i]
        if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
            i += 1
            features['V_NOT{}'.format(document[i])] = (document[i] in word_features)
        else:
            features['V_{}'.format(word)] = (word in word_features)
    return features

# %%
## cross-validation ##
# this function takes the number of folds, the feature sets and the labels
# it iterates over the folds, using different sections for training and testing in turn
#   it prints the performance for each fold and the average performance at the end
def cross_validation_PRF(num_folds, featuresets, labels):
    subset_size = int(len(featuresets)/num_folds)
    print('Each fold size:', subset_size)
    # for the number of labels - start the totals lists with zeroes
    num_labels = len(labels)
    total_precision_list = [0] * num_labels
    total_recall_list = [0] * num_labels
    total_F1_list = [0] * num_labels

    # iterate over the folds
    for i in range(num_folds):
        test_this_round = featuresets[(i*subset_size):][:subset_size]
        train_this_round = featuresets[:(i*subset_size)] + featuresets[((i+1)*subset_size):]
        # train using train_this_round
        classifier = nltk.NaiveBayesClassifier.train(train_this_round)
        # evaluate against test_this_round to produce the gold and predicted labels
        goldlist = []
        predictedlist = []
        for (features, label) in test_this_round:
            goldlist.append(label)
            predictedlist.append(classifier.classify(features))


        # computes evaluation measures for this fold and
        #   returns list of measures for each label
        print('Fold', i)
        (precision_list, recall_list, F1_list) \
                  = eval_measures(goldlist, predictedlist, labels)
        # take off triple string to print precision, recall and F1 for each fold
        '''
        print('\tPrecision\tRecall\t\tF1')
        # print measures for each label
        for i, lab in enumerate(labels):
            print(lab, '\t', "{:10.3f}".format(precision_list[i]), \
              "{:10.3f}".format(recall_list[i]), "{:10.3f}".format(F1_list[i]))
        '''
        # for each label add to the sums in the total lists
        for i in range(num_labels):
            # for each label, add the 3 measures to the 3 lists of totals
            total_precision_list[i] += precision_list[i]
            total_recall_list[i] += recall_list[i]
            total_F1_list[i] += F1_list[i]

    # find precision, recall and F measure averaged over all rounds for all labels
    # compute averages from the totals lists
    precision_list = [tot/num_folds for tot in total_precision_list]
    recall_list = [tot/num_folds for tot in total_recall_list]
    F1_list = [tot/num_folds for tot in total_F1_list]
    # the evaluation measures in a table with one row per label
    print('\nAverage Precision\tRecall\t\tF1 \tPer Label')
    # print measures for each label
    for i, lab in enumerate(labels):
        print(lab, '\t', "{:10.3f}".format(precision_list[i]), \
          "{:10.3f}".format(recall_list[i]), "{:10.3f}".format(F1_list[i]))
    
    # print macro average over all labels - treats each label equally
    print('\nMacro Average Precision\tRecall\t\tF1 \tOver All Labels')
    print('\t', "{:10.3f}".format(sum(precision_list)/num_labels), \
          "{:10.3f}".format(sum(recall_list)/num_labels), \
          "{:10.3f}".format(sum(F1_list)/num_labels))

    # for micro averaging, weight the scores for each label by the number of items
    #    this is better for labels with imbalance
    # first intialize a dictionary for label counts and then count them
    label_counts = {}
    for lab in labels:
      label_counts[lab] = 0 
    # count the labels
    for (doc, lab) in featuresets:
      label_counts[lab] += 1
    # make weights compared to the number of documents in featuresets
    num_docs = len(featuresets)
    label_weights = [(label_counts[lab] / num_docs) for lab in labels]
    print('\nLabel Counts', label_counts)
    #print('Label weights', label_weights)
    # print macro average over all labels
    print('Micro Average Precision\tRecall\t\tF1 \tOver All Labels')
    precision = sum([a * b for a,b in zip(precision_list, label_weights)])
    recall = sum([a * b for a,b in zip(recall_list, label_weights)])
    F1 = sum([a * b for a,b in zip(F1_list, label_weights)])
    print( '\t', "{:10.3f}".format(precision), \
      "{:10.3f}".format(recall), "{:10.3f}".format(F1))

# %%
##THIS CODE GETS THE DATA REQUIRED FOR EVALUATING THE MODEL:
def eval_measures(gold, predicted, labels):    
    # these lists have values for each label 
    recall_list = []
    precision_list = []
    F1_list = []
    for lab in labels:
        # for each label, compare gold and predicted lists and compute values
        TP = FP = FN = TN = 0
        for i, val in enumerate(gold):
            if val == lab and predicted[i] == lab:  TP += 1
            if val == lab and predicted[i] != lab:  FN += 1
            if val != lab and predicted[i] == lab:  FP += 1
            if val != lab and predicted[i] != lab:  TN += 1
        # use these to compute recall, precision, F1
        # for small numbers, guard against dividing by zero in computing measures
        if (TP == 0) or (FP == 0) or (FN == 0):
          recall_list.append (0)
          precision_list.append (0)
          F1_list.append(0)
        else:
          recall = TP / (TP + FP)
          precision = TP / (TP + FN)
          recall_list.append(recall)
          precision_list.append(precision)
          F1_list.append( 2 * (recall * precision) / (recall + precision))

    # the evaluation measures in a table with one row per label
    return (precision_list, recall_list, F1_list)

# %% [markdown]
# __Started file: random sample__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    featuresets = [(document_features(d, word_features), c) for (d, c) in docs]

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, featuresets, labels)
    
    train_set, test_set = featuresets[round(.1*int(limit)):], featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds,featuresets))

# %%
dirPath0 = os.getcwd()
dirPath = dirPath0+'/corpus'
print(dirPath)
process(dirPath, 10000)
# Out:
# C:\Users\aivii\programsmm\FP736/corpus
# Read 25000 phrases, using 10000 random phrases
# (['``', 'i', 'am', 'not', 'sure', 'who', 'is', 'writing', 'these', 'glowing', 'reviews', 'for', 'this', 'movie', 'but', 'trust', 'me', 'it', 'stkinks', '.', 'i', 'have', 'seen', 'hundreds', 'of', 'horror', 'films', 'and', 'slasher', 'flicks', 'and', 'this', 'one', 'is', 'lame', 'it', 'is', 'only', 'about', '80min', 'long', 'and', 'believe', 'me', 'that', 'is', 'all', 'i', 'could', 'take', '.', 'plot', 'is', 'terrible'], 'negative')
# (['``', 'this', 'is', 'a', 'so', 'called', "'feel-good", "'", 'movies'], 'positive')
# (['``', 'as', 'a', 'gamer'], 'negative')
# (['``', 'raising', 'victor', 'vargas', 'is', 'just', 'a', 'bad', 'film', '.', 'no', 'amount', 'of', 'denial', 'or', 'ad-dollar', 'supported', 'publicity', 'with', 'change', 'this', 'sad', 'fact', '.', 'maybe', 'peter', 'sollett', 'saw', 'he', 'did', "n't", 'have', 'the', 'money', 'to', 'do', 'the', 'movie', 'he', 'wanted', 'to', 'make', 'and', 'decided', 'to', 'take', 'the', 'easy', 'way', 'out', 'by', 'making', 'a', 'bad', 'film', 'that', 'cynically', 'apes', 'the', 'tenets', 'of', 'current', '``', "''", 'edgy', 'film-making', "''", "''", '.', 'maybe', 'he', 'just', 'does', "n't", 'know', 'any', 'better', '.', 'it', "'s", 'hard', 'to', 'tell', '.', 'what', "'s", 'not', 'hard', 'to', 'tell', 'is', 'the', 'result', '.', 'except', 'for', 'a', 'few', 'viewers', 'who', 'will', 'intellectualize', 'the', 'bad', 'film-making', 'into', 'an', 'attempt', 'at', 'pseudo-realism'], 'negative')
# (['``', 'when', 'this', 'film', 'was', 'made'], 'positive')
# (['the', 'arch', 'title', 'does', "n't", 'fit', 'this', 'gentle', 'romantic', 'comedy', '.', 'donna', 'reed', 'and', 'tom', 'drake', 'do', "n't", 'have', 'much', 'chemistry', '--', 'but', 'their', 'characters', 'are', "n't", 'supposed', 'to', '.', 'both', 'are', 'extremely', 'likable', 'and', 'attractive', '.', 'the', 'supporting', 'cast', 'is', 'a', 'dream', '--', 'with', 'the', 'exception', 'of', 'sig', 'ruman', "'s", 'annoying', 'faux', 'russian', '.'], 'positive')
# (['``', 'it', 'seems', 'as', 'if', 'in', 'science', 'fiction', 'you', 'have', 'this', 'periodic', 'throwback', 'to', 'perform', 'an', 'odd', 'phenomenon', 'that', 'appears', 'in', 'long', 'serial', 'novels', '.', 'it', "'s", 'where', 'the', 'first', 'novel', '(', 'dune'], 'negative')
# (['``', 'i', 'would', "n't", 'go', 'so', 'far', 'as', 'to', 'not', 'recommend', 'this', 'movie'], 'positive')
# (['``', 'with', 'all', 'the', 'european', 'studios', 'involved', 'in', 'this', 'one'], 'negative')
# (['``', 'the', '1930', "'", 'were', 'a', 'golden', 'age', 'of', 'los', 'angeles', 'with', 'its', 'film', 'industry', 'and', 'great', 'potential', 'of', 'various', 'other', 'possibilities', 'to', 'become', 'rich', 'and', 'famous', 'and', 'happy', '.', 'people', 'were', 'arriving', 'there', 'hoping', 'to', 'fulfill', 'their', 'dreams', '.', 'expecting', 'open', 'arms', 'and', 'welcoming', 'offers', 'there', 'were', 'only', 'a', 'few', 'who', 'managed', 'to', 'succeed', 'and', 'find', 'their', 'way', 'to', 'stardom'], 'negative')
# 20679
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.597      0.712      0.649
# positive 	      0.753      0.647      0.696
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.675      0.680      0.672
#
# Label Counts {'negative': 5053, 'positive': 4947}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.674      0.680      0.672
# Overall Accuracy 0.64
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<356>146 |
# negative | 214<284>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.674
# 1 0.6645
# 2 0.6775
# 3 0.67
# 4 0.685
# mean accuracy 0.6742
# None

# %% [markdown]
# __Starter file(wiith seed)__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    featuresets = [(document_features(d, word_features), c) for (d, c) in docs]

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, featuresets, labels)
    
    train_set, test_set = featuresets[round(.1*int(limit)):], featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds,featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20584
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.591      0.717      0.647
# positive 	      0.774      0.662      0.713
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.682      0.689      0.680
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.684      0.689      0.681
# Overall Accuracy 0.68
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<381>134 |
# negative | 186<299>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.682
# 1 0.685
# 2 0.6865
# 3 0.676
# 4 0.69
# mean accuracy 0.6839000000000001
# None

# %% [markdown]
# __Stop words removed__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent, cat) in docs for word in sent if word not in stopwords] # with stop words removed
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    featuresets = [(document_features(d, word_features), c) for (d, c) in docs]

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, featuresets, labels)
    
    train_set, test_set = featuresets[round(.1*int(limit)):], featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds,featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20438
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.613      0.711      0.658
# positive 	      0.758      0.669      0.711
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.686      0.690      0.684
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.687      0.690      0.685
# Overall Accuracy 0.689
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<387>128 |
# negative | 183<302>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.684
# 1 0.6835
# 2 0.686
# 3 0.6825
# 4 0.698
# mean accuracy 0.6868000000000001
# None

# %% [markdown]
# __Negation features(with stop words)__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent, cat) in docs for word in sent if word not in stopwords] # with stop words removed
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

   # this list of negation words includes some "approximate negators" like hardly and rarely
    #negationwords = ['no', 'not', 'never', 'none', 'nowhere', 'nothing', 'noone', 'rather', 'hardly', 'scarcely', 'rarely', 'seldom', 'neither', 'nor']
    

  # Not_feature sets from a feature definition function
    NOT_featuresets = [(Not_features(d, word_features, negationwords), c) for (d, c) in docs]
    print(len(NOT_featuresets))

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, NOT_featuresets, labels)
        
    train_set, test_set = NOT_featuresets[round(.1*int(limit)):], NOT_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds,NOT_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20438
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.670      0.713      0.691
# positive 	      0.738      0.698      0.718
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.704      0.705      0.704
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.705      0.705      0.704
# Overall Accuracy 0.713
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<384>131 |
# negative | 156<329>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.708
# 1 0.7055
# 2 0.7065
# 3 0.693
# 4 0.7115
# mean accuracy 0.7049000000000001
# None

# %% [markdown]
# __Negation features(stop words removed)__

# %%
stopwords = nltk.corpus.stopwords.words('english')
#print(len(stopwords)) #179
#print(stopwords)

# remove some negation words 
negationwords.extend(['ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn'])

newstopwords = [word for word in stopwords if word not in negationwords]
#print(len(newstopwords)) #157

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    # remove stop words from the all words list
    new_all_words_list = [word for (sent,cat) in docs for word in sent if word not in newstopwords]
    
  # continue to define a new all words dictionary, get the 2000 most common as new_word_features
    new_all_words = nltk.FreqDist(new_all_words_list)
    new_word_items = new_all_words.most_common(2000)

 
    new_word_features = [word for (word,count) in new_word_items]
    
    
    # this list of negation words includes some "approximate negators" like hardly and rarely
    #negationwords = ['no', 'not', 'never', 'none', 'nowhere', 'nothing', 'noone', 'rather', 'hardly', 'scarcely', 'rarely', 'seldom', 'neither', 'nor']
    

  # Not_feature sets from a feature definition function
    NOT_featuresets = [(Not_features(d, new_word_features, negationwords), c) for (d, c) in docs]
    print(len(NOT_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, NOT_featuresets, labels)
        
    train_set, test_set = NOT_featuresets[round(.1*int(limit)):], NOT_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, NOT_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.660      0.714      0.686
# positive 	      0.744      0.694      0.718
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.702      0.704      0.702
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.703      0.704      0.702
# Overall Accuracy 0.712
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<387>128 |
# negative | 160<325>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.703
# 1 0.7045
# 2 0.7035
# 3 0.6915
# 4 0.713
# mean accuracy 0.7031
# None

# %% [markdown]
# __Bigrams pmi__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent, cat) in docs for word in sent if word not in stopwords] # with stop words removed
    all_words = nltk.FreqDist(all_words_list)
    # print(len(all_words))
    
    finder = BigramCollocationFinder.from_words(all_words_list)
    bigram_features = finder.nbest(bigram_measures.pmi, 500)

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    bigram_featuresets = [(bigram_document_features(d, word_features, bigram_features), c) for (d, c) in docs]
    print(len(bigram_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, bigram_featuresets, labels)
        
    train_set, test_set = bigram_featuresets[round(.1*int(limit)):], bigram_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (bigram_features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(bigram_features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, bigram_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.612      0.713      0.659
# positive 	      0.762      0.670      0.713
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.687      0.691      0.686
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.688      0.691      0.686
# Overall Accuracy 0.692
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<391>124 |
# negative | 184<301>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.685
# 1 0.684
# 2 0.689
# 3 0.6815
# 4 0.7005
# mean accuracy 0.6880000000000001
# None

# %% [markdown]
# __Bigrams chi_square__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent, cat) in docs for word in sent if word not in stopwords] # with stop words removed
    all_words = nltk.FreqDist(all_words_list)
    # print(len(all_words))
    
    finder = BigramCollocationFinder.from_words(all_words_list)
    bigram_features = finder.nbest(bigram_measures.chi_sq, 500)

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    bigram_featuresets = [(bigram_document_features(d, word_features, bigram_features), c) for (d, c) in docs]
    print(len(bigram_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, bigram_featuresets, labels)
        
    train_set, test_set = bigram_featuresets[round(.1*int(limit)):], bigram_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (bigram_features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(bigram_features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, bigram_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.612      0.713      0.659
# positive 	      0.762      0.670      0.713
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.687      0.691      0.686
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.688      0.691      0.686
# Overall Accuracy 0.692
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<391>124 |
# negative | 184<301>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.685
# 1 0.684
# 2 0.689
# 3 0.6815
# 4 0.7005
# mean accuracy 0.6880000000000001
# None

# %% [markdown]
# __Bigrams raw_freq__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent, cat) in docs for word in sent if word not in stopwords] # with stop words removed
    all_words = nltk.FreqDist(all_words_list)
    # print(len(all_words))
    
    finder = BigramCollocationFinder.from_words(all_words_list)
    bigram_features = finder.nbest(bigram_measures.raw_freq, 500)

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    bigram_featuresets = [(bigram_document_features(d, word_features, bigram_features), c) for (d, c) in docs]
    print(len(bigram_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, bigram_featuresets, labels)
        
    train_set, test_set = bigram_featuresets[round(.1*int(limit)):], bigram_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (bigram_features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(bigram_features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, bigram_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.609      0.713      0.657
# positive 	      0.762      0.668      0.712
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.686      0.691      0.684
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.687      0.690      0.685
# Overall Accuracy 0.695
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<393>122 |
# negative | 183<302>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.684
# 1 0.6795
# 2 0.6895
# 3 0.681
# 4 0.701
# mean accuracy 0.687
# None

# %% [markdown]
# __SL__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # SL_feature sets from a feature definition function
    #featuresets = [(document_features(d, word_features), c) for (d, c) in docs]
    SL_featuresets = [(SL_features(d, word_features, SL), c) for (d, c) in docs]
    print(len(SL_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, SL_featuresets, labels)
        
    train_set, test_set = SL_featuresets[round(.1*int(limit)):], SL_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, SL_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20584
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.594      0.713      0.648
# positive 	      0.768      0.662      0.711
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.681      0.687      0.679
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.682      0.687      0.680
# Overall Accuracy 0.688
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<382>133 |
# negative | 179<306>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.6755
# 1 0.685
# 2 0.68
# 3 0.6735
# 4 0.698
# mean accuracy 0.6824000000000001
# None

# %% [markdown]
# __SL stop words removed__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    # remove stop words from the all words list
    new_all_words_list = [word for (sent,cat) in docs for word in sent if word not in newstopwords]
    new_all_words = nltk.FreqDist(new_all_words_list)
    print(len(new_all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    new_word_items = new_all_words.most_common(2000)
    new_word_features = [word for (word,count) in new_word_items]

  # SL_feature sets from a feature definition function
    #featuresets = [(document_features(d, word_features), c) for (d, c) in docs]
    SL_featuresets = [(SL_features(d, new_word_features, SL), c) for (d, c) in docs]
    print(len(SL_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, SL_featuresets, labels)
        
    train_set, test_set = SL_featuresets[round(.1*int(limit)):], SL_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, SL_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20455
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.610      0.714      0.658
# positive 	      0.763      0.669      0.713
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.686      0.691      0.685
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.688      0.691      0.686
# Overall Accuracy 0.695
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<392>123 |
# negative | 182<303>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.681
# 1 0.692
# 2 0.6815
# 3 0.6815
# 4 0.7025
# mean accuracy 0.6877
# None

# %% [markdown]
# __Negation and bigrams together__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]
    
    finder = BigramCollocationFinder.from_words(all_words_list)
    bigram_features = finder.nbest(bigram_measures.raw_freq, 500)

  # not_feature sets from a feature definition function
    not_featuresets = [(not_features(d, word_features, bigram_features, negationwords), c) for (d, c) in docs]
    print(len(not_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, not_featuresets, labels)
        
    train_set, test_set = not_featuresets[round(.1*int(limit)):], not_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, not_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'this', 'third', 'pokemon', 'movie', 'is', 'too', 'abstract', 'for', 'younger', 'kids', 'to', 'follow', 'and', 'too', 'repetitious', 'to', 'entertain', 'older', 'kids', '.', 'the', 'message', 'of', 'the', 'film', '--', 'about', 'dealing', 'with', 'loss', '--', 'is', 'subverted', 'by', 'the', 'return', 'of', 'the', 'young', 'girl', "'s", 'father', 'during', 'the', 'film', "'s", 'credits', '.', 'team', 'rocket', 'provide', 'some', 'amusement'], 'negative')
# (['``', 'this', 'movie', 'has', 'a', 'special', 'way', 'of', 'telling', 'the', 'story'], 'positive')
# (['``', 'watching', 'a', 'videotaped', 'replay', 'of', 'about', '8', 'various', '1994-1997', 'spider-man', 'cartoons', 'made', 'me', 'realize', 'why', 'i', 'could', "n't", 'stomach', 'it', 'when', 'it', 'first', 'came', 'out', '.', 'i', "'m", 'from', 'the', 'old', 'school'], 'negative')
# (['``', 'i', 'bought', 'this', 'dvd', 'without', 'any', 'previous', 'reference', 'but', 'the', 'names', 'of', 'john', 'huston'], 'negative')
# (['``', 'one', 'of', 'the', 'best', 'records', 'of', 'israel', "'s", 'response', 'to', 'the', 'murder', 'of', 'rabin.extremely', 'true', 'and', 'natural'], 'positive')
# (['``', 'hayao', 'miyazaki', 'name', 'became', 'prominent', 'with', 'spitied', 'away'], 'positive')
# (['``', 'if', '...', '.', 'is', 'the', 'cinematic', 'equivalent', 'of', 'sgt', '.', 'pepper', "'s", ':', 'revered', 'by', 'baby', 'boomers', 'as', 'the', 'pinnacle', 'of', 'creation'], 'negative')
# (['``', 'here', 'is', 'what', 'happened', ':', '1', ')', 'head', 'of', 'bbc3', 'needs', 'to', 'make', 'programmes', 'aimed', 'at', 'different', 'audience', 'to', 'bbc1', 'and', 'bbc2', 'to', 'keep', 'licence', 'and', 'job', '.', '2', ')', 'lenny', 'henry', 'offers', 'his', 'unfunny', 'friends', 'up', '.', '3', ')', 'head', 'of', 'bbc3', 'snaps', 'them', 'up'], 'negative')
# (['``', 'i', 'saw', 'this', 'film', 'at', 'the', 'santa', 'barbara', 'film', 'festival'], 'positive')
# (['``', 'this', 'is', 'a', '``', "''", 'b', 'series', "''", "''", 'film', 'noir'], 'positive')
# 20445
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.631      0.724      0.674
# positive 	      0.767      0.683      0.722
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.699      0.703      0.698
#
# Label Counts {'negative': 4914, 'positive': 5086}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.700      0.703      0.699
# Overall Accuracy 0.709
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<414>106 |
# negative | 185<295>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.709
# 1 0.709
# 2 0.696
# 3 0.7005
# 4 0.6865
# mean accuracy 0.7001999999999999
# None

# %% [markdown]
# __All combined__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]
    
    finder = BigramCollocationFinder.from_words(all_words_list)
    bigram_features = finder.nbest(bigram_measures.chi_sq, 500)

  # not_feature sets from a feature definition function
    combined_featuresets = [(combined_document_features(d, word_features,SL, bigram_features, negationwords), c) for (d, c) in docs]
    print(len(combined_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, combined_featuresets, labels)
        
    train_set, test_set = combined_featuresets[round(.1*int(limit)):], combined_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds, combined_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20584
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.631      0.732      0.677
# positive 	      0.776      0.685      0.727
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.703      0.708      0.702
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.704      0.708      0.703
# Overall Accuracy 0.717
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<402>113 |
# negative | 170<315>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.708
# 1 0.7055
# 2 0.704
# 3 0.689
# 4 0.716
# mean accuracy 0.7045
# None

# %%
process(dirPath, 5000)
# Out:
# Read 25000 phrases, using 5000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 14041
# 5000
# Each fold size: 1000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.603      0.703      0.649
# positive 	      0.752      0.661      0.703
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.677      0.682      0.676
#
# Label Counts {'negative': 2461, 'positive': 2539}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.678      0.682      0.677
# Overall Accuracy 0.672
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<188> 66 |
# negative |  98<148>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 1000
# 0 0.674
# 1 0.666
# 2 0.689
# 3 0.675
# 4 0.691
# mean accuracy 0.6789999999999999
# None

# %% [markdown]
# __Negation and SL__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    #featuresets = [(document_features(d, word_features), c) for (d, c) in docs]
    c_featuresets = [(generate_SLneg_features(d, SL, word_features), c) for (d, c) in docs]
    print(len(c_featuresets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, c_featuresets, labels)
        
    train_set, test_set = c_featuresets[round(.1*int(limit)):], c_featuresets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    #print(cross_validation_accuracy(num_folds, combined_featuresets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'probably', 'the', 'best', 'film', 'of', 'the', 'year', 'for', 'me', '.', 'this', 'small', 'french', 'film', 'centers', 'on', 'put', 'upon', 'office', 'secretary', 'carla', '(', 'emmanuelle', 'devos', ')', 'who', 'spends', 'her', 'days', 'doing', 'other', 'men', "'s", 'jobs'], 'positive')
# (['``', 'i', 'came', 'away', 'from', 'this', 'movie', 'with', 'the', 'feeling', 'that', 'it', 'could', 'have', 'been', 'so', 'much', 'better', '.', 'instead', 'of', 'what', 'should', 'be', 'a', 'gripping'], 'negative')
# (['i', 'have', 'a', 'two', 'year', 'old', 'son', 'who', 'suffers', 'from', 'the', 'same', 'condition', 'as', 'jonny', 'kennedy', '.', 'i', 'never', 'got', 'the', 'chance', 'to', 'meet', 'him', 'but', 'i', 'have', 'never', 'heard', 'anybody', 'say', 'a', 'bad', 'word', 'about', 'him', '.', 'i', 'hope', 'he', 'knows', 'how', 'much', 'the', 'making', 'of', 'this', 'programme', 'has', 'helped', 'his', 'fellow', 'sufferers', 'by', 'raising', 'awareness', 'of', 'this', 'terrible', 'condition', '.', 'this', 'man', 'has', 'touched', 'people', 'in', 'a', 'way', 'that', 'a', 'million', 'charity', 'leaflets', 'could', 'not', '.', 'i', 'believe', 'that', 'this', 'should', 'be', 'compulsory', 'viewing', 'in', 'schools', '.', 'i', 'also', 'agree', 'with', 'other', 'comments', '-', 'what', 'have', 'i', 'got', 'to', 'moan', 'about', '?', 'he', 'took', 'everything', 'that', 'life', 'could', 'throw', 'at', 'him', 'and', 'still', 'managed', 'to', 'retain', 'a', 'sense', 'of', 'humour', '.', 'god', 'bless', '.', 'i', 'could', "n't", 'watch', 'the', 'part', 'that', 'showed', 'his', 'dressings', 'being', 'changed', '.', 'i', 'have', 'enough', 'trouble', 'with', 'my', 'son', "'s", '.'], 'positive')
# (['``', 'it', 'is', 'always', 'sad', 'when', '``', "''", 'fringe', "''", "''", 'movies', 'such', 'as', 'this', 'are', 'overlooked', 'by', 'the', 'majority', 'of', 'filmgoers', '.', '``', '``', 'panic', "''", "''", 'is', 'a', 'wonderfully', 'compelling', 'and', 'poignant', 'study', 'of', 'a', 'character', 'who', 'feels', 'trapped', 'in', 'the', 'pointlessness', 'of', 'his', 'own', 'life', '.', 'william', 'h.', 'macy'], 'positive')
# (['``', 'i', 'think', 'this', 'film', 'has', 'much', 'to', 'recommend', 'it'], 'positive')
# (['``', 'ahista', 'ahista', 'is', 'one', 'little', 'small', 'brilliant', '.', 'i', 'started', 'watching', 'it'], 'positive')
# (['``', 'would', 'that', 'more', 'romantic', 'comedies', 'were', 'as', 'deftly', 'executed', 'as', 'this', 'one', '?', 'i', 'never', 'thought', 'anything', 'as', 'mundane', 'as', 'the', 'simple', 'sale', 'of', 'a', 'music', 'box', 'could', 'leave', 'me', 'catching', 'my', 'breath', 'with', 'excitement', '.', 'margaret', 'sullavan', 'makes', 'a', 'marvellous', 'saleswoman'], 'positive')
# (['``', 'herculis', 'puaro', 'is'], 'negative')
# (['``', 'second-feature', 'concerns', 'a', 'young', 'woman', 'in', 'london', 'desperate', 'for', 'a', 'job'], 'positive')
# (['``', 'i', 'finally', 'sat', 'down', 'and', 'saw', 'this', 'film', 'the', 'whole', 'way', 'through'], 'positive')
# 20471
# {'length': 33, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 98, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 39, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 39, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 64, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 78, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 50, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 60, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 71, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 40, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 3.03}
# {'length': 17, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 31, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 3.23}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 53, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 0}
# {'length': 16, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 47, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0}
# {'length': 4, 'negationwords': 1}
# {'length': 7, 'negationwords': 1}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 48, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 0}
# {'length': 9, 'negationwords': 1}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 66, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0}
# {'length': 28, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 3.57}
# {'length': 5, 'negationwords': 1}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 50, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 2, 'negationwords': 1}
# {'length': 6, 'negationwords': 0}
# {'length': 20, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 5.0}
# {'length': 38, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 48, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 80, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 9.09, 'percnegative': 0.0}
# {'length': 30, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 3.33}
# {'length': 69, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 5.26, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 84, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 41, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 123, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 10, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 44, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 7.14}
# {'length': 44, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 30, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 85, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 27, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 3.7}
# {'length': 6, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5}
# {'length': 29, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 58, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 1.72}
# {'length': 8, 'negationwords': 0}
# {'length': 18, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 5.56}
# {'length': 10, 'negationwords': 1}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 98, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 0}
# {'length': 17, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 5.88}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 45, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 67, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 27, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 36, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 15, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 31, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 31, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 109, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 2, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 46, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 61, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 76, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 70, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 9, 'negationwords': 0}
# {'length': 11, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 9.09, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2}
# {'length': 9, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 5, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 66, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 2, 'negationwords': 1}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 12, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 45, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 21, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 4.76, 'percnegative': 0.0}
# {'length': 42, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 64, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 66, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 1.52}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 5, 'negationwords': 1}
# {'length': 9, 'negationwords': 1}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 78, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 1.28}
# {'length': 92, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 49, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 2.04}
# {'length': 6, 'negationwords': 1}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2}
# {'length': 28, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 3.57}
# {'length': 24, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 47, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 39, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 2.56, 'percnegative': 0.0}
# {'length': 68, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 62, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 53, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 41, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 29, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 3.45, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 38, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 90, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 68, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 30, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 10, 'negationwords': 1}
# {'length': 25, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 4.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 9.09, 'percnegative': 0.0}
# {'length': 30, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 0}
# {'length': 7, 'negationwords': 1}
# {'length': 8, 'negationwords': 1}
# {'length': 48, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 31, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 10, 'negationwords': 0}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 52, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 1.92, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 37, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 0}
# {'length': 21, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 8, 'negationwords': 1}
# {'length': 60, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 109, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 4, 'negationwords': 1}
# {'length': 24, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 4.17}
# {'length': 3, 'negationwords': 0}
# {'length': 10, 'negationwords': 1}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 27, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 42, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 10, 'negationwords': 1}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 5.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 40, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 66, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 1.52}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 0, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 63, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 50, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 42, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 45, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 4.35}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 33, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 36, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 2.78, 'percnegative': 0.0}
# {'length': 50, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 47, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 92, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 59, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 4.76, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 31, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 65, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 44, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 36, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 92, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 1.09}
# {'length': 36, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 55, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 57, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 43, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 65, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 48, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 63, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 7, 'negationwords': 1}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 0}
# {'length': 39, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 45, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 43, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 9.09, 'percnegative': 0.0}
# {'length': 42, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 63, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 40, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 2.5, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5}
# {'length': 4, 'negationwords': 1}
# {'length': 141, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 0.71, 'percnegative': 0.0}
# {'length': 42, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 9, 'negationwords': 1}
# {'length': 33, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 71, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 0}
# {'length': 46, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 58, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 103, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 16, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 6.25}
# {'length': 20, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 13, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 55, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 79, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 27, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 43, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 2.33}
# {'length': 20, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 5.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 106, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 5.56}
# {'length': 10, 'negationwords': 1}
# {'length': 19, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 0, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 4.35, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 27, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 3, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 10, 'negationwords': 1}
# {'length': 6, 'negationwords': 1}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 68, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 6, 'negationwords': 1}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 85, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 5, 'negationwords': 1}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 79, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 16, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 37, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 0}
# {'length': 113, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5}
# {'length': 32, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 62, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 62, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 78, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 142, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 36, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 39, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 27, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 46, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 27, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 8, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 75, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 1.33}
# {'length': 10, 'negationwords': 1}
# {'length': 32, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 85, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 1.18, 'percnegative': 0.0}
# {'length': 37, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 27, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 3.7, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 6.25}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 44, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 12, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 71, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 53, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 4.76}
# {'length': 89, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 1.12, 'percnegative': 0.0}
# {'length': 41, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 76, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 40, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0}
# {'length': 20, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 43, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 81, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 36, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 58, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 5, 'negationwords': 1}
# {'length': 59, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 0}
# {'length': 32, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 3.12, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 4.35, 'percnegative': 0.0}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 40, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 76, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 124, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 31, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 48, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 54, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 1.85, 'percnegative': 0.0}
# {'length': 66, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 1.52, 'percnegative': 0.0}
# {'length': 78, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 49, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 31, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 7.14}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 32, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 113, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 39, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 44, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# ...
# {'length': 45, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 47, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 89, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 75, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 1.33, 'percnegative': 0.0}
# {'length': 30, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 29, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 4.55, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 43, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 2.33, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 3.85, 'percnegative': 0.0}
# {'length': 86, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 4, 'negationwords': 1}
# {'length': 10, 'negationwords': 1}
# {'length': 5, 'negationwords': 1}
# {'length': 7, 'negationwords': 1}
# {'length': 5, 'negationwords': 1}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 8, 'negationwords': 1}
# {'length': 9, 'negationwords': 1}
# {'length': 19, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 75, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 5, 'negationwords': 0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 25, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 4.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 68, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 81, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 43, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 26, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 2, 'negationwords': 1}
# {'length': 35, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 2, 'negationwords': 1}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 80, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 54, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 45, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 6.25, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 40, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 2.5, 'percnegative': 0.0}
# {'length': 41, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 24, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 4.17, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 22, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 4.55}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 8, 'negationwords': 1}
# {'length': 39, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 30, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 48, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 2.08, 'percnegative': 0.0}
# {'length': 37, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 41, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 26, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 56, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 63, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 42, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 22, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 4.55, 'percnegative': 0.0}
# {'length': 59, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 94, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 75, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 32, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1}
# {'length': 6, 'negationwords': 1}
# {'length': 10, 'negationwords': 1}
# {'length': 4, 'negationwords': 1}
# {'length': 3, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5}
# {'length': 48, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 2, 'percpositive': 0.0, 'percnegative': 1.96}
# {'length': 7, 'negationwords': 1}
# {'length': 38, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 65, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 51, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 7, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 68, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 1.47}
# {'length': 67, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 3.03, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 14, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 17, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 13, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 64, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 29, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 10, 'negationwords': 1}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 4.35}
# {'length': 4, 'negationwords': 1}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 0}
# {'length': 16, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 0}
# {'length': 27, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 23, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 62, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 5, 'negationwords': 1}
# {'length': 64, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 50, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 32, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 33, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 3.03, 'percnegative': 0.0}
# {'length': 59, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 4, 'negationwords': 1}
# {'length': 57, 'negationwords': 0, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 1.75, 'percnegative': 0.0}
# {'length': 8, 'negationwords': 1}
# {'length': 18, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 47, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 0}
# {'length': 7, 'negationwords': 1}
# {'length': 44, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 2.27}
# {'length': 2, 'negationwords': 1}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 15, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 32, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0}
# {'length': 7, 'negationwords': 1}
# {'length': 83, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 9, 'negationwords': 1}
# {'length': 12, 'negationwords': 0, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 8.33}
# {'length': 24, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 2, 'negationwords': 1}
# {'length': 8, 'negationwords': 1}
# {'length': 28, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 16, 'negationwords': 1, 'positiveStrengthCount': 5, 'negativeStrengthCount': 0, 'percpositive': 6.25, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 21, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 10, 'negationwords': 1}
# {'length': 8, 'negationwords': 1}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 36, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 12, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 73, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 2, 'negationwords': 1}
# {'length': 26, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 19, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 5.26, 'percnegative': 0.0}
# {'length': 37, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 3, 'negationwords': 1}
# {'length': 20, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 28, 'negationwords': 1, 'positiveStrengthCount': 2, 'negativeStrengthCount': 0, 'percpositive': 3.57, 'percnegative': 0.0}
# {'length': 6, 'negationwords': 1}
# {'length': 68, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 46, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 2.17}
# {'length': 8, 'negationwords': 1}
# {'length': 7, 'negationwords': 1}
# {'length': 10, 'negationwords': 1}
# {'length': 8, 'negationwords': 1}
# {'length': 67, 'negationwords': 0, 'percpositive': 0.0, 'percnegative': 0.0}
# {'length': 34, 'negationwords': 1, 'positiveStrengthCount': 0, 'negativeStrengthCount': 5, 'percpositive': 0.0, 'percnegative': 2.94}
# {'length': 11, 'negationwords': 1, 'percpositive': 0.0, 'percnegative': 0.0}
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.479      0.503      0.490
# positive 	      0.541      0.517      0.528
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.510      0.510      0.509
#
# Label Counts {'negative': 4923, 'positive': 5077}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.510      0.510      0.509
# Overall Accuracy 0.522
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<312>198 |
# negative | 280<210>|
# ---------+---------+
# (row = reference; col = test)

# %% [markdown]
# __LIWC__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    liwcfeaturesets = [(liwc_features(d, word_features, poslist, neglist), c) for (d, c) in docs]
    print(len(liwcfeaturesets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, liwcfeaturesets, labels)
        
    train_set, test_set = liwcfeaturesets[round(.1*int(limit)):], liwcfeaturesets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds,liwcfeaturesets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'spoiler', '!', '!', '!', 'this', 'movie', 'is', 'based', 'on', 'the', 'concept', 'of', 'what', 'if', '?', 'of', 'course', 'mr', 'destiny', 'will', 'be', 'able', 'to', 'answer', 'this', 'question', '.', 'the', 'main', 'character', 'goes', 'through', 'a', 'bad', 'day'], 'positive')
# (['``', 'the', 'actors', 'did', 'a', 'really', 'good', 'job', 'playing', 'their', 'roles', '--', 'particularly', 'the', 'mom', '.', 'however'], 'negative')
# (['``', 'i', 'saw', 'not', 'so', 'fabulous', 'rating', 'on', 'imdb'], 'negative')
# (['``', 'the', 'title', 'overstates', 'the', 'content', 'of', 'this', 'movie', 'somewhat'], 'positive')
# (['``', 'broadway', 'and', 'film', 'actor-turned-director', 'john', 'cassavetes', '(', 'from', 'rosemary', "'s", 'baby', ')', 'creates', 'a', 'masterpiece', 'with', 'this', '1977', 'film', '.', 'it', 'stars', 'gena', 'rowlands'], 'positive')
# (['``', 'a', 'classy', 'film', 'pulled', 'in', '2', 'directions', '.', 'to', 'its', 'advantage', 'it', 'is', 'directed', 'by', 'wes', 'craven', '.', 'on', 'the', 'downside', 'the', 'tv', 'film', 'budget', 'shows', 'what', 'could', 'have', 'been', 'so', 'much', 'more', 'with', 'a', 'larger', 'budget', '.', 'it', 'moves', 'along', 'as', 'susan', 'lucci', 'draws', 'robert', 'urichfamily', 'into', 'her', 'clutches', 'and', 'trying', 'to', 'persuade', 'him', 'into', 'the', 'secret', 'of', 'her', 'health', 'club', '.', 'his', 'latest', 'invention'], 'positive')
# (['``', 'i', 'loved', 'this', 'movie', '!', 'it', 'was', 'all', 'i', 'could', 'do', 'not', 'to', 'break', 'down', 'into', 'tears', 'while', 'watching', 'it'], 'positive')
# (['``', 'massacre', 'is', 'a', 'film', 'directed', 'by', 'andrea', 'bianchi', '(', 'burial', 'ground', ')', 'and', 'produced', 'by', 'legendary', 'italian', 'horror', 'director', 'lucio', 'fulci', '.', 'now', 'with', 'this', 'mix', 'of', 'great', 'talent', 'you', 'would', 'think', 'this', 'movie', 'would', 'have', 'been', 'a', 'true', 'gore', 'fest', '.', 'this', 'could', 'not', 'be', 'further', 'from', 'that', '.', 'massacre', 'falls', 'right', 'on', 'its', 'face', 'as', 'being', 'one', 'of', 'the', 'most', 'boring', 'slasher', 'films', 'i', 'have', 'seen', 'come', 'out', 'of', 'italian', 'cinema', '.', 'i', 'was', 'actually', 'struggling', 'to', 'stay', 'awake', 'during', 'the', 'film', 'and', 'i', 'have', 'never', 'had', 'that', 'problem', 'with', 'italian', 'horror', 'films', '.', 'massacre', 'starts', 'out', 'with', 'a', 'hooker', 'being', 'slaughtered', 'on', 'the', 'side', 'of', 'the', 'road', 'with', 'an', 'ax', '.', 'this', 'scene', 'was', 'used', 'in', 'fulci', "'s", 'nightmare', 'concert', '.', 'this', 'is', "n't", 'a', 'bad', 'scene', 'and', 'it', 'raises', 'your', 'expectations', 'of', 'the', 'movie', 'as', 'being', 'an', 'ax', 'wielding', 'slaughter', '.', 'unfortuanitly'], 'negative')
# (['``', 'dana', 'andrews', 'stands', '``', "''", 'where', 'the', 'sidewalk', 'ends', "''", "''", 'in', 'this', '1950', 'film', 'that', 'also', 'stars', 'gene', 'tierney'], 'positive')
# (['``', 'elephant', 'walk', 'may', 'not', 'be', 'the', 'acme', 'of', 'literature', 'or', 'of', 'film'], 'positive')
# 20436
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.632      0.717      0.671
# positive 	      0.752      0.673      0.710
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.692      0.695      0.690
#
# Label Counts {'negative': 4982, 'positive': 5018}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.692      0.695      0.691
# Overall Accuracy 0.695
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<380>121 |
# negative | 184<315>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.687
# 1 0.6975
# 2 0.691
# 3 0.684
# 4 0.6995
# mean accuracy 0.6918
# None

# %% [markdown]
# __SL + LIWC__

# %%
## function to read kaggle training file, train and test a classifier 
def process(dirPath,limitStr):
    limit = int(limitStr)
    dirPath = '/Users/aivii/programsmm/FP736/corpus/'
    f = open('./corpus/train.csv','r', encoding='utf-8')
    phrasedata = []
    for line in f:
        if (not line.startswith(',label')): # ignore the first line 
            line = line.strip()
        #line = fp.readline()
            phrasedata.append(line.split(',')[1:3])
  
  # pick a random sample of length limit because of phrase overlapping sequences
    random.Random(1234).shuffle(phrasedata)
    phraselist = phrasedata[:limit]

    print('Read', len(phrasedata), 'phrases, using', len(phraselist), 'random phrases')
  
  # create list of phrase documents as (list of words, label)
    phrasedocs = []
  # add all the phrases

  # each phrase has a list of tokens and the sentiment label ( 0 or 1)
    for phrase in phraselist:
        tokens = nltk.word_tokenize(phrase[1])
        
        # phrasedocs.append((tokens, int(phrase[0])))
        sentiment = int(phrase[0])
        
        if (sentiment == 0):
            phrasedocs.append((tokens, 'negative'))
        if (sentiment == 1):
            phrasedocs.append((tokens, 'positive'))


  # possibly filter tokens
  # lowercase - each phrase is a pair consisting of a token list and a label
    docs = []
    for phrase in phrasedocs:
        lowerphrase = ([w.lower() for w in phrase[0]], phrase[1])
        docs.append (lowerphrase)
  # print a few
    for phrase in docs[:10]:
        print (phrase)

  # continue as usual to get all words and create word features
    all_words_list = [word for (sent,cat) in docs for word in sent]
    all_words = nltk.FreqDist(all_words_list)
    print(len(all_words))

  # get the 2000 most frequently appearing keywords in the corpus
    word_items = all_words.most_common(2000)
    word_features = [word for (word,count) in word_items]

  # feature sets from a feature definition function
    SLliwcfeaturesets = [(SL_liwc_features(d, word_features, SL,poslist, neglist), c) for (d, c) in docs]
    print(len(SLliwcfeaturesets)) # 100

  # train classifier and show performance in cross-validation
  # make a list of labels
    label_list = [c for (d,c) in docs]
    labels = list(set(label_list))    # gets only unique labels
    num_folds = 5
    cross_validation_PRF(num_folds, SLliwcfeaturesets, labels)
        
    train_set, test_set = SLliwcfeaturesets[round(.1*int(limit)):], SLliwcfeaturesets[:round(.1*int(limit))]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    print('Overall Accuracy', nltk.classify.accuracy(classifier, test_set))
    
    goldlist = [] # gold labels for the test set
    predictedlist = [] # test list, predicted 
    for (features, label) in test_set:
        goldlist.append(label)
        predictedlist.append(classifier.classify(features))
    cm = nltk.ConfusionMatrix(goldlist, predictedlist)
    print(cm.pretty_format(sort_by_count=True, truncate=9))
    
    print(cross_validation_accuracy(num_folds,SLliwcfeaturesets))

# %%
process(dirPath, 10000)
# Out:
# Read 25000 phrases, using 10000 random phrases
# (['``', 'hundstage', 'is', 'an', 'intentionally', 'ugly', 'and', 'unnerving', 'study', 'of', 'life', 'in', 'a', 'particularly', 'dreary', 'suburb', 'of', 'vienna', '.', 'it', 'comes', 'from', 'former', 'documentary', 'director', 'ulrich', 'seidl', 'who', 'adopts', 'a', 'very', 'documentary-like', 'approach', 'to', 'the', 'material', '.', 'however'], 'positive')
# (['``', 'oh', 'dear', 'we', 'do', "n't", 'like', 'it', 'when', 'our', 'super-hero', 'love', 'interest', 'develops', 'a', 'brain', 'do', 'we', '?', 'something', 'has', 'happened', 'to', 'people'], 'positive')
# (['``', 'been', 'lurking', 'for', 'a', 'couple', 'of', 'years', 'or', 'so', '.', 'i', 'have', 'never', 'been', 'moved', 'to', 'post', 'on', 'here', 'before'], 'negative')
# (['``', 'any', 'story', 'comprises', 'a', 'premise'], 'positive')
# (['``', 'in', 'my', 'humble', 'opinion'], 'negative')
# (['``', 'there', 'are', 'movies', 'like', '``', "''", 'plan', '9', "''", "''", 'that', 'are', 'so', 'bad', 'they', 'have', 'a', 'charm', 'about', 'them'], 'negative')
# (['``', 'caution', ':', 'may', 'contain', 'spoilers', '...', 'i', "'ve", 'seen', 'this', 'movie', '3', 'times', '&', 'i', "'ve", 'liked', 'it', 'every', 'time', '.', 'upon', 'seeing', 'it', 'again'], 'positive')
# (['``', 'how', 'can', 'you', 'sum', 'up', 'just', 'exactly', 'how', 'feelgood', 'and', 'right', 'and', 'touching', 'this', 'film', 'is', '?', '?', 'for', 'several', 'weeks', 'this', 'dvd', 'leaped', 'off', 'the', 'shelf', 'at', 'me', 'every', 'time', 'i', 'went', 'in', 'the', 'store', '-', 'having', 'seen', 'steve', 'carrell', 'in', 'a', 'couple', 'of', 'films', 'previously'], 'positive')
# (['``', 'i', 'have', 'to', 'say', 'the', 'worst', 'part', 'of', 'the', 'movie', 'was', 'the', 'first', 'half', 'hour', '.', 'i', 'was', 'really', 'confused', 'about', 'who', 'was', 'who', '.', 'for', 'example'], 'positive')
# (['``', '****', '=', 'a', 'masterpiece', 'to', 'be', 'recorded', 'in', 'the', 'books', 'and', 'never', 'forgotten', '***1/2', '=', 'a', 'classic', 'in', 'time', ';', 'simply', 'a', 'must', 'see', '***', '=', 'a', 'solid'], 'positive')
# 20584
# 10000
# Each fold size: 2000
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
#
# Average Precision	Recall		F1 	Per Label
# negative 	      0.587      0.714      0.644
# positive 	      0.772      0.659      0.711
#
# Macro Average Precision	Recall		F1 	Over All Labels
# 	      0.680      0.687      0.677
#
# Label Counts {'negative': 4918, 'positive': 5082}
# Micro Average Precision	Recall		F1 	Over All Labels
# 	      0.681      0.686      0.678
# Overall Accuracy 0.692
#          |   p   n |
#          |   o   e |
#          |   s   g |
#          |   i   a |
#          |   t   t |
#          |   i   i |
#          |   v   v |
#          |   e   e |
# ---------+---------+
# positive |<393>122 |
# negative | 186<299>|
# ---------+---------+
# (row = reference; col = test)
#
# Each fold size: 2000
# 0 0.673
# 1 0.6795
# 2 0.6805
# 3 0.6715
# 4 0.7005
# mean accuracy 0.6809999999999999
# None
